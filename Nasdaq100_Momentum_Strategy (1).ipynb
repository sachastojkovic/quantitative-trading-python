# %% [markdown]
# # Quantitative Trading Strategy: Nasdaq-100 Momentum
#
# ## Objective
#
# This project develops and evaluates a simple momentum trading strategy based on the 50-day moving average of the QQQ ETF.
#
# ## Methodology
#
# - Download historical market data using yfinance.
# - Calculate daily returns.
# - Build a moving-average trading signal.
# - Backtest the strategy.
# - Compare its performance with a buy-and-hold benchmark.
# - Evaluate total return, annualized volatility, Sharpe ratio and maximum drawdown.
#
# ## Tools
#
# Python, Pandas, NumPy, Matplotlib, yfinance.
#
# ## Disclaimer
#
# This project is for educational purposes only and does not constitute investment advice.

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.13/dist-packages (0.2.66)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.13/dist-packages (from yfinance) (2.2.3)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.13/dist-packages (from yfinance) (2.1.3)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.13/dist-packages (from yfinance) (2.32.4)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.13/dist-packages (from yfinance) (0.0.13)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from yfinance) (4.11.7)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.13/dist-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.13/dist-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.13/dist-packages (from yfinance) (4.4.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.13/dist-packages (from yfinance) (4.13.5)
# Requirement already satisfied: curl_cffi>=0.7 in /usr/local/lib/python3.13/dist-packages (from yfinance) (0.16.2)
# Requirement already satisfied: protobuf>=3.19.0 in /usr/local/lib/python3.13/dist-packages (from yfinance) (5.29.6)
# Requirement already satisfied: websockets>=13.0 in /usr/local/lib/python3.13/dist-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.13/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.9.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.13/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (4.16.0)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from curl_cffi>=0.7->yfinance) (2.1.1)
# Requirement already satisfied: certifi>=2024.2.2 in /usr/local/lib/python3.13/dist-packages (from curl_cffi>=0.7->yfinance) (2026.7.22)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas>=1.3.0->yfinance) (2026.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests>=2.31->yfinance) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests>=2.31->yfinance) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests>=2.31->yfinance) (2.5.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi>=2.0.0->curl_cffi>=0.7->yfinance) (3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = yf.download(
    "QQQ",
    start="2015-01-01",
    end="2026-01-01",
    auto_adjust=True
                  )
data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open    Volume
# Ticker            QQQ        QQQ        QQQ        QQQ       QQQ
# Date
# 2015-01-02  94.561150  95.718586  94.101847  95.314405  31314600
# 2015-01-05  93.174049  94.258003  92.907653  94.147768  36521300
# 2015-01-06  91.924736  93.467992  91.511367  93.311831  66205500
# 2015-01-07  93.109749  93.330212  92.310560  92.531031  37577400
# 2015-01-08  94.891853  95.075571  93.798712  93.899759  40212600

# %%
prices = data["Close"]
prices = prices.squeeze()
prices.head()
# Out:
# Date
# 2015-01-02    94.561150
# 2015-01-05    93.174049
# 2015-01-06    91.924736
# 2015-01-07    93.109749
# 2015-01-08    94.891853
# Name: QQQ, dtype: float64

# %%
plt.figure(figsize=(12, 5))
plt.plot(prices)
plt.title("Prix de l'ETF QQQ")
plt.xlabel("Date")
plt.ylabel("Prix ajusté")
plt.grid()
plt.show()

# %% [markdown]
# Let's start now the quantitative aspect of our project, we will calculate a mobile mean at 50 days :
# - If price > mean : we invest
# - If price < mean : we stay in cash

# %%
data_strategy = pd.DataFrame()
data_strategy["Price"] = prices
data_strategy["MA50"] = (
    data_strategy["Price"]
    .rolling(window=50)
    .mean()
)
data_strategy.head(60)
# Out:
#                  Price       MA50
# Date
# 2015-01-02   94.561150        NaN
# 2015-01-05   93.174049        NaN
# 2015-01-06   91.924736        NaN
# 2015-01-07   93.109749        NaN
# 2015-01-08   94.891853        NaN
# 2015-01-09   94.267212        NaN
# 2015-01-12   93.284294        NaN
# 2015-01-13   93.256706        NaN
# 2015-01-14   92.742317        NaN
# 2015-01-15   91.538940        NaN
# 2015-01-16   92.613678        NaN
# 2015-01-20   93.348587        NaN
# 2015-01-21   93.826279        NaN
# 2015-01-22   95.562424        NaN
# 2015-01-23   95.773697        NaN
# 2015-01-26   95.663475        NaN
# 2015-01-27   93.183243        NaN
# 2015-01-28   92.705544        NaN
# 2015-01-29   93.596596        NaN
# 2015-01-30   92.870911        NaN
# 2015-02-02   93.679306        NaN
# 2015-02-03   94.579552        NaN
# 2015-02-04   94.496819        NaN
# 2015-02-05   95.314392        NaN
# 2015-02-06   94.735672        NaN
# 2015-02-09   94.432556        NaN
# 2015-02-10   95.902306        NaN
# 2015-02-11   96.251366        NaN
# 2015-02-12   97.372093        NaN
# 2015-02-13   98.208008        NaN
# 2015-02-17   98.299850        NaN
# 2015-02-18   98.437668        NaN
# 2015-02-19   98.924522        NaN
# 2015-02-20   99.585907        NaN
# 2015-02-23   99.686966        NaN
# 2015-02-24   99.760437        NaN
# 2015-02-25   99.512413        NaN
# 2015-02-26  100.017662        NaN
# 2015-02-27   99.576721        NaN
# 2015-03-02  100.476967        NaN
# 2015-03-03  100.008484        NaN
# 2015-03-04   99.622643        NaN
# 2015-03-05   99.797203        NaN
# 2015-03-06   98.667320        NaN
# 2015-03-09   98.952095        NaN
# 2015-03-10   97.114861        NaN
# 2015-03-11   96.554535        NaN
# 2015-03-12   97.188347        NaN
# 2015-03-13   96.765823        NaN
# 2015-03-16   98.015099  96.076661
# 2015-03-17   98.171265  96.148863
# 2015-03-18   99.135788  96.268098
# 2015-03-19   99.282738  96.415258
# 2015-03-20   99.925415  96.551571
# 2015-03-23   99.732086  96.648376
# 2015-03-24   99.373001  96.750491
# 2015-03-25   97.098824  96.826782
# 2015-03-26   96.767403  96.896996
# 2015-03-27   97.154068  96.985231
# 2015-03-30   98.268127  97.119815

# %%
data_strategy["Signal"] = np.where(
    data_strategy["Price"] > data_strategy["MA50"], 1, 0
)

# %%
data_strategy.tail()
# Out:
#                  Price        MA50  Signal
# Date
# 2025-12-24  622.460266  612.965096       1
# 2025-12-26  622.420288  613.412938       1
# 2025-12-29  619.407410  613.844960       1
# 2025-12-30  617.970764  614.169734       1
# 2025-12-31  612.862854  614.240706       0

# %%
data_strategy["Market_Return"] = (
    data_strategy["Price"].pct_change()
)

# %%
data_strategy["Strategy_Return"] = (
    data_strategy["Signal"].shift(1)
    * data_strategy["Market_Return"]
)

# %%
data_strategy = data_strategy.dropna()

# %%
data_strategy["Buy_Hold"] = (
    1 + data_strategy["Market_Return"]
).cumprod()

data_strategy["Momentum_Strategy"] = (
    1 + data_strategy["Strategy_Return"]
).cumprod()

# %%
plt.figure(figsize=(12, 6))

plt.plot(
    data_strategy.index,
    data_strategy["Buy_Hold"],
    label="Buy & Hold QQQ"
)

plt.plot(
    data_strategy.index,
    data_strategy["Momentum_Strategy"],
    label="Momentum MA50"
)

plt.title("QQQ: Buy & Hold vs Momentum MA50")
plt.xlabel("Date")
plt.ylabel("Cumulative Wealth")

plt.legend()
plt.grid(True)

plt.savefig(
    "performance_comparison.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
buy_hold_total = (
    data_strategy["Buy_Hold"].iloc[-1] - 1
)

momentum_total = (
    data_strategy["Momentum_Strategy"].iloc[-1] - 1
)

print("Rendement Buy & Hold :", round(buy_hold_total * 100, 2), "%")
print("Rendement Momentum :", round(momentum_total * 100, 2), "%")
# Out:
# Rendement Buy & Hold : 533.35 %
# Rendement Momentum : 231.08 %

# %%
volatility_buy_hold = (
    data_strategy["Market_Return"]
    .std() * np.sqrt(252)
)
volatility_momentum = (
    data_strategy["Strategy_Return"]
    .std() * np.sqrt(252)
)
print(
    "Volatilité Buy & Hold :",
    round(volatility_buy_hold * 100, 2),
    "%"
)

print(
    "Volatilité Momentum :",
    round(volatility_momentum * 100, 2),
    "%"
)
# Out:
# Volatilité Buy & Hold : 22.09 %
# Volatilité Momentum : 13.92 %

# %%
annual_return_buy_hold = (
    data_strategy["Market_Return"].mean() * 252
)

annual_return_momentum = (
    data_strategy["Strategy_Return"].mean() * 252
)

sharpe_buy_hold = (
    annual_return_buy_hold / volatility_buy_hold
)

sharpe_momentum = (
    annual_return_momentum / volatility_momentum
)

print(
    "Sharpe Buy & Hold :",
    round(sharpe_buy_hold, 2)
)

print(
    "Sharpe Momentum :",
    round(sharpe_momentum, 2)
)
# Out:
# Sharpe Buy & Hold : 0.89
# Sharpe Momentum : 0.87

# %%
def max_drawdown(performance):
  peak = performance.cummax()
  drawdown = performance / peak -1
  return drawdown.min()

# %%
dd_buy_hold = max_drawdown(
    data_strategy["Buy_Hold"]
)

dd_momentum = max_drawdown(
    data_strategy["Momentum_Strategy"]
)

print(
    "Max Drawdown Buy & Hold :",
    round(dd_buy_hold * 100, 2),
    "%"
)

print(
    "Max Drawdown Momentum :",
    round(dd_momentum * 100, 2),
    "%"
)
# Out:
# Max Drawdown Buy & Hold : -35.12 %
# Max Drawdown Momentum : -18.87 %

# %%
results = pd.DataFrame({
    "Strategy": [
        "Buy & Hold QQQ",
        "Momentum MA50"
    ],
    "Total Return": [
        buy_hold_total,
        momentum_total
    ],
    "Volatility": [
        volatility_buy_hold,
        volatility_momentum
    ],
    "Sharpe Ratio": [
        sharpe_buy_hold,
        sharpe_momentum
    ],
    "Max Drawdown": [
        dd_buy_hold,
        dd_momentum
    ]
})

results
# Out:
#          Strategy  Total Return  Volatility  Sharpe Ratio  Max Drawdown
# 0  Buy & Hold QQQ      5.333464    0.220855      0.886043     -0.351187
# 1   Momentum MA50      2.310752    0.139227      0.867506     -0.188711

# %%
results_display = results.copy()

results_display["Total Return"] = (
    results_display["Total Return"] * 100
).round(2).astype(str) + "%"

results_display["Volatility"] = (
    results_display["Volatility"] * 100
).round(2).astype(str) + "%"

results_display["Max Drawdown"] = (
    results_display["Max Drawdown"] * 100
).round(2).astype(str) + "%"

results_display["Sharpe Ratio"] = (
    results_display["Sharpe Ratio"].round(2)
)

results_display
# Out:
#          Strategy Total Return Volatility  Sharpe Ratio Max Drawdown
# 0  Buy & Hold QQQ      533.35%     22.09%          0.89      -35.12%
# 1   Momentum MA50      231.08%     13.92%          0.87      -18.87%

# %%
def drawdown_series(performance):
    peak = performance.cummax()
    return performance / peak - 1

dd_buy_hold_series = drawdown_series(
    data_strategy["Buy_Hold"]
)

dd_momentum_series = drawdown_series(
    data_strategy["Momentum_Strategy"]
)

plt.figure(figsize=(12, 5))

plt.plot(
    dd_buy_hold_series,
    label="Buy & Hold"
)

plt.plot(
    dd_momentum_series,
    label="Momentum MA50"
)

plt.title("Strategies drawdown")
plt.xlabel("Date")
plt.ylabel("Drawdown")

plt.legend()
plt.grid()

plt.show()
